# %% [markdown]
# #**Pandas**

# %%
import pandas as pd

# %% [markdown]
# #**MatplotLib**

# %%
pd.DataFrame({'Weight': [50, 45], 'Height': [155, 166]})
# Out:
#    Weight  Height
# 0      50     155
# 1      45     166

# %%
pd.DataFrame({'Barbie': ['I liked it.', 'It was awful.'],
              'Ken': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                   Barbie           Ken
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.DataFrame({'Americano': ['20','25','18'],
              'Cappucino': ['22','30','21'],
              'Latte':['23','29','10']},
             index=['Coffee Shop#1','Coffee Shop2#','Coffee Shop 3#'])
# Out:
#                Americano Cappucino Latte
# Coffee Shop#1         20        22    23
# Coffee Shop2#         25        30    29
# Coffee Shop 3#        18        21    10

# %%
fruits_list = ['Apple', 'Banana', 'Orange','Mango']
fruits_df = pd.DataFrame(fruits_list, index=['Fruit 1', 'Fruit 2', 'Fruit 3', 'Fruit 4'], columns=['Fruits'])
fruits_df
# Out:
#          Fruits
# Fruit 1   Apple
# Fruit 2  Banana
# Fruit 3  Orange
# Fruit 4   Mango

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/ds_students .csv')
df
# Out:
#     Student ID                       Name  Age   Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31   53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32   37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19  ขาดสอบ   NaN      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18      65    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21      62     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20    60.5     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18     NaN   NaN         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19   51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19   64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18   28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร   -15    24.5     E      Ang Thong
# ...

# %%
df.head(3)
# Out:
#    Student ID                    Name  Age   Score Grade   Province
# 0   644295001           นายณัฐธีรา เย   31   53.75     D    Songkla
# 1   644295002     นายณัฐวัฒน์ บุญหวาน   32   37.65     E    Bangkok
# 2   644295003   นายดนัยเทพ ดำเกลี้ยง    19  ขาดสอบ   NaN  Chiangmai

# %%
df.tail(3)
# Out:
#     Student ID                    Name  Age  Score Grade       Province
# 17   644295022    นายวีระวัฒน์ ฤทธิ์โต   19   88.5     A  Nakhon Pathom
# 18   644295023   นายศรีสุภัทรเดช บุบผา   19  29.38     E        Bangkok
# 19   644295024       นายธนากร นกเขียว    18  75.13     B        Bangkok

# %%
#เลือกคอลลัมบ์ที่มีเฉพาะตัวเลข
df.describe()
# Out:
#          Student ID        Age
# count  2.000000e+01  20.000000
# mean   6.442950e+08  18.600000
# std    7.437282e+00   8.834144
# min    6.442950e+08 -15.000000
# 25%    6.442950e+08  18.000000
# 50%    6.442950e+08  19.000000
# 75%    6.442950e+08  20.000000
# max    6.442950e+08  32.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Age         20 non-null     int64
#  3   Score       19 non-null     object
#  4   Grade       18 non-null     object
#  5   Province    20 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
#แสดงจำนวนค่า Null ของแต่ละคอลลัมบ์
df.isnull().sum()
# Out:
# Student ID    0
# Name          0
# Age           0
# Score         1
# Grade         2
# Province      0
# dtype: int64

# %%
#แสดงข้อมูลในคอลลัมบ์ Score ว่ามี "ขาดสอบ" แถวไหนบ้าง
df['Score']=='ขาดสอบ'
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Score, dtype: bool

# %%
#ให้แสดงแถวที่มีข้อมูล "ขาดสอบ"
df[df['Score']=='ขาดสอบ']
# Out:
#    Student ID                    Name  Age   Score Grade   Province
# 2   644295003   นายดนัยเทพ ดำเกลี้ยง    19  ขาดสอบ   NaN  Chiangmai

# %%
#ทำให้ "ขาดสอบ" กลายเป็น 0
df.loc[df['Score']=='ขาดสอบ','Score'] = 0
df
# Out:
#     Student ID                       Name  Age  Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31  53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32  37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19      0   NaN      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18     65    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21     62     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20   60.5     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18    NaN   NaN         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19  51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19  64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18  28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร   -15   24.5     E      Ang Thong
# ...

# %%
df['Score'].fillna(0,inplace=True)

# %%
df
# Out:
#     Student ID                       Name  Age  Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31  53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32  37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19      0   NaN      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18     65    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21     62     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20   60.5     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18      0   NaN         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19  51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19  64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18  28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร   -15   24.5     E      Ang Thong
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Age         20 non-null     int64
#  3   Score       20 non-null     object
#  4   Grade       18 non-null     object
#  5   Province    20 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB
#          Student ID        Age
# count  2.000000e+01  20.000000
# mean   6.442950e+08  18.600000
# std    7.437282e+00   8.834144
# min    6.442950e+08 -15.000000
# 25%    6.442950e+08  18.000000
# 50%    6.442950e+08  19.000000
# 75%    6.442950e+08  20.000000
# max    6.442950e+08  32.000000

# %%
df.loc[df['Grade']=='NaN','Grade'] = 'E'
df
# Out:
#     Student ID                       Name  Age  Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31  53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32  37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19      0   NaN      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18     65    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21     62     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20   60.5     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18      0   NaN         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19  51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19  64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18  28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร   -15   24.5     E      Ang Thong
# ...

# %%
df['Grade'].fillna('E',inplace=True)
df
# Out:
#     Student ID                       Name  Age  Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31  53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32  37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19      0     E      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18     65    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21     62     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20   60.5     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18      0     E         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19  51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19  64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18  28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร   -15   24.5     E      Ang Thong
# ...

# %%
df['Score'] = df['Score'].astype(float)

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Age         20 non-null     int64
#  3   Score       20 non-null     float64
#  4   Grade       20 non-null     object
#  5   Province    20 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.1+ KB
# None
#          Student ID        Age      Score
# count  2.000000e+01  20.000000  20.000000
# mean   6.442950e+08  18.600000  45.577000
# std    7.437282e+00   8.834144  23.686149
# min    6.442950e+08 -15.000000   0.000000
# 25%    6.442950e+08  18.000000  29.097500
# 50%    6.442950e+08  19.000000  52.750000
# 75%    6.442950e+08  20.000000  60.875000
# max    6.442950e+08  32.000000  88.500000

# %%
mean_age=df.loc[df['Age']>0 , 'Age'].mean().astype(int)
mean_age
# Out:
# 20

# %%
df.loc[df['Age']<=0 , 'Age']=mean_age
df
# Out:
#     Student ID                       Name  Age  Score Grade       Province
# 0    644295001              นายณัฐธีรา เย   31  53.75     D        Songkla
# 1    644295002        นายณัฐวัฒน์ บุญหวาน   32  37.65     E        Bangkok
# 2    644295003      นายดนัยเทพ ดำเกลี้ยง    19   0.00     E      Chiangmai
# 3    644295004    นางสาวประวีณา พูนเพียร    18  65.00    C+        Bangkok
# 4    644295005   นางสาวศุภาพิชญ์ บุญภักดี   21  62.00     C           Yala
# 5    644295006       นายรัชชานนท์ ไชยหาญ    20  60.50     C      Chiangrai
# 6    644295007          นายสฟีร เส็นบัตร    18   0.00     E         Phuket
# 7    644295009            นายซุลฟีฟี มิง    19  51.75     D        Bangkok
# 8    644295011           นายหิบรีย์ คชสาร   19  64.75     C            Nan
# 9    644295013    นางสาวแวสาฟียะห์ ดอเลาะ   18  28.25     E          Krabi
# 10   644295014          นายพชร กาญจนเพชร    20  24.50     E      Ang Thong
# ...

# %%
df.drop(['Student ID', 'Name'], axis=1, inplace=True)

# %%
df
# Out:
#     Age  Score Grade       Province
# 0    31  53.75     D        Songkla
# 1    32  37.65     E        Bangkok
# 2    19   0.00     E      Chiangmai
# 3    18  65.00    C+        Bangkok
# 4    21  62.00     C           Yala
# 5    20  60.50     C      Chiangrai
# 6    18   0.00     E         Phuket
# 7    19  51.75     D        Bangkok
# 8    19  64.75     C            Nan
# 9    18  28.25     E          Krabi
# 10   20  24.50     E      Ang Thong
# 11   20  56.25    D+        Kalasin
# 12   19  17.25     E   Kanchanaburi
# 13   18  59.63    D+        Lampang
# 14   21  54.50     D        Bangkok
# 15   20  32.75     E   Mae Hong Son
# 16   18  50.00     D           Loei
# 17   19  88.50     A  Nakhon Pathom
# 18   19  29.38     E        Bangkok
# 19   18  75.13     B        Bangkok

# %%
df[df['Grade'].isin(['A','E'])]
# Out:
#     Age  Score Grade       Province
# 1    32  37.65     E        Bangkok
# 2    19   0.00     E      Chiangmai
# 6    18   0.00     E         Phuket
# 9    18  28.25     E          Krabi
# 10   20  24.50     E      Ang Thong
# 12   19  17.25     E   Kanchanaburi
# 15   20  32.75     E   Mae Hong Son
# 17   19  88.50     A  Nakhon Pathom
# 18   19  29.38     E        Bangkok

# %%
df.iloc[3:7, 1:3]
# Out:
#    Score Grade
# 3   65.0    C+
# 4   62.0     C
# 5   60.5     C
# 6    0.0     E

# %%
df['new_Score']=df['Score']+5
df
# Out:
#     Age  Score Grade       Province  new_Score
# 0    31  53.75     D        Songkla      58.75
# 1    32  37.65     E        Bangkok      42.65
# 2    19   0.00     E      Chiangmai       5.00
# 3    18  65.00    C+        Bangkok      70.00
# 4    21  62.00     C           Yala      67.00
# 5    20  60.50     C      Chiangrai      65.50
# 6    18   0.00     E         Phuket       5.00
# 7    19  51.75     D        Bangkok      56.75
# 8    19  64.75     C            Nan      69.75
# 9    18  28.25     E          Krabi      33.25
# 10   20  24.50     E      Ang Thong      29.50
# 11   20  56.25    D+        Kalasin      61.25
# 12   19  17.25     E   Kanchanaburi      22.25
# 13   18  59.63    D+        Lampang      64.63
# 14   21  54.50     D        Bangkok      59.50
# 15   20  32.75     E   Mae Hong Son      37.75
# 16   18  50.00     D           Loei      55.00
# 17   19  88.50     A  Nakhon Pathom      93.50
# 18   19  29.38     E        Bangkok      34.38
# ...

# %%
df['new_Score_Age']=df['Score']+df['Age']
df
# Out:
#     Age  Score Grade       Province  new_Score  new_Score_Age
# 0    31  53.75     D        Songkla      58.75          84.75
# 1    32  37.65     E        Bangkok      42.65          69.65
# 2    19   0.00     E      Chiangmai       5.00          19.00
# 3    18  65.00    C+        Bangkok      70.00          83.00
# 4    21  62.00     C           Yala      67.00          83.00
# 5    20  60.50     C      Chiangrai      65.50          80.50
# 6    18   0.00     E         Phuket       5.00          18.00
# 7    19  51.75     D        Bangkok      56.75          70.75
# 8    19  64.75     C            Nan      69.75          83.75
# 9    18  28.25     E          Krabi      33.25          46.25
# 10   20  24.50     E      Ang Thong      29.50          44.50
# 11   20  56.25    D+        Kalasin      61.25          76.25
# 12   19  17.25     E   Kanchanaburi      22.25          36.25
# 13   18  59.63    D+        Lampang      64.63          77.63
# ...

# %%
df.boxplot()
# Out:
# <Axes: >
