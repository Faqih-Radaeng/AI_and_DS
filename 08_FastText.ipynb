# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/data/cooking.stackexchange.tar.gz && tar xvzf cooking.stackexchange.tar.gz
# Out:
# --2023-10-11 03:50:45--  https://dl.fbaipublicfiles.com/fasttext/data/cooking.stackexchange.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.35.7.82, 13.35.7.38, 13.35.7.50, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.35.7.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 457609 (447K) [application/x-tar]
# Saving to: ‘cooking.stackexchange.tar.gz’
#
# cooking.stackexchan 100%[===================>] 446.88K  --.-KB/s    in 0.02s
#
# 2023-10-11 03:50:45 (25.8 MB/s) - ‘cooking.stackexchange.tar.gz’ saved [457609/457609]
#
# cooking.stackexchange.id
# cooking.stackexchange.txt
# readme.txt

# %%
# !head cooking.stackexchange.txt
# Out:
# __label__sauce __label__cheese How much does potato starch affect a cheese sauce recipe?
# __label__food-safety __label__acidity Dangerous pathogens capable of growing in acidic environments
# __label__cast-iron __label__stove How do I cover up the white spots on my cast iron stove?
# __label__restaurant Michelin Three Star Restaurant; but if the chef is not there
# __label__knife-skills __label__dicing Without knife skills, how can I quickly and accurately dice vegetables?
# __label__storage-method __label__equipment __label__bread What's the purpose of a bread box?
# __label__baking __label__food-safety __label__substitutions __label__peanuts how to seperate peanut oil from roasted peanuts at home?
# __label__chocolate American equivalent for British chocolate terms
# __label__baking __label__oven __label__convection Fan bake vs bake
# ...

# %%
# !cat cooking.stackexchange.txt | sed -e "s/\([.\!?,'/()]\)/ \1 /g" | tr "[:upper:]" "[:lower:]" > cooking.preprocessed.txt
# !head -n 12404 cooking.stackexchange.txt > cooking.train
# !tail -n 3000 cooking.stackexchange.txt > cooking.valid

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199771 sha256=f463d9c003655f8190aa3f29817b3b33d034df0cf5250114a82a651e69f609f8
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
import fasttext
model = fasttext.train_supervised(input="cooking.train", epoch=25)

model.test("cooking.valid", k=5)
# Out:
# (3000, 0.1762, 0.381000432463601)

# %%
model.predict("how to seperate peanut oil from roasted peanuts at home?")
# Out:
# (('__label__oil',), array([0.10262051]))

# %%
model.predict("how to seperate peanut oil from roasted peanuts at home?", k=5)
# Out:
# (('__label__oil',
#   '__label__baking',
#   '__label__food-safety',
#   '__label__frying',
#   '__label__deep-frying'),
#  array([0.10262051, 0.03879666, 0.03069961, 0.02778637, 0.02093217]))

# %%
# !gdown 1zdIhZfT4Zc-EIywk4DHfziQths7HrTIm
# !gdown 1sRZ-BNOK3X_GC46NbDxhXpJ34UbTebEw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zdIhZfT4Zc-EIywk4DHfziQths7HrTIm
# To: /content/burger.train
# 100% 28.7k/28.7k [00:00<00:00, 63.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sRZ-BNOK3X_GC46NbDxhXpJ34UbTebEw
# To: /content/burger.test
# 100% 4.45k/4.45k [00:00<00:00, 15.9MB/s]

# %%
# !head burger.train
# Out:
# __label__neg ไป ที่ สาขา ปั๊ม คาลเท็กซ์ ประ ชานุ กู ซื้อ พาย ไก่ และ พาย เผือก อย่าง ละ ชิ้น กลับ บ้าน จะ ทาน พาย ไก่ เปิด มา กลายเป็น พาย เชอรี่ ทั้งสอง ชิ้น เลย แย่จัง
# __label__neg bk ทุก สาขา บริการ ดี โดยเฉพาะอย่างยิ่ง เอม โพ เรียม แม้กระทั่ง พารากอน ที่ คน เยอะ ก็ บริการ ดี และ คุณภาพ อาหาร ดีมาก แต่ แปลก มาก ที่ สาขา เซ็นทรัลเวิลด์ เป็น สาขา ที่ มี มาตรฐาน ต่ำ มาก ทั้ง เรื่อง อาหาร และ บริการ เคย ไว้ ไป หนึ่ง ครั้ง พนักงานบริการ แย่มาก จน รู้สึก ได้ มัน ทอด โรย เกลือ จน กิน ไม่ ได้ เอา ไป เปลี่ยน ก็ หน้าถอดสี ตอนนั้น คิด ว่า คง โชคร้าย อีก สอง เดือน ต่อมา ไป ทาน อีกที ก็ ยัง เหมือนเดิม บริการ และ มาตรฐาน อาหาร แย่ สุด อยากรู้ ว่า เขา แยก บริหาร สาขา นี้ ออกจาก สาขา อื่น หรือเปล่า ทำไม คุณภาพ ได้ ต่ำ แบบนี้ ขอ ชมเชย เอม โพ เรียม และ พารากอน ด้วยใจจริง เซ็นทรัลเวิลด์ ถ้า ไป คง เลือก กิน ร้าน อื่น เสียความรู้สึก มาก ทั้ง ผจก และ พน
# ...

# %%
# !head burger.test
# Out:
# __label__neg ไป ทาน สาขา emquatier สั่ง วอ เปอร์ หมู มา ได้ เนื้อ แทน ซะงั้น ความประทับใจ ไม่ มี เหลือ
# __label__neg ผม เคย เป็น แฟน เบอร์เกอร์ คิง แต่ ปัจจุบัน คุณภาพ ลดลง มหาศาล จึง ต้อง ขอ บอกลา ทั้ง ที่ มี โปรโมชั่น ออกมา อย่าง ต่อเนื่อง ปัจจุบัน เนื้อ คุณภาพ ปานกลาง แต่ มา เจอ การย่าง เนื้อ ระดับ แย่ ผล ก็ คือ ความ ไม่ อร่อย และ ราคา เดียวกัน นี้ หา เบอร์เกอร์ ที่อื่น ทาน ได้ อร่อย กว่า มาก ราคา อาหาร เกือบ เท่ากับ เบอร์เกอร์ คิง ต่างประเทศ แต่ ผม ไม่ เข้าใจ ว่า ทำไม คุณภาพ ได้ ต่างกัน ลิบลับ ขนาด นี้
# __label__neg ผม แค่ สอบถาม พน ว่า ลด ใช่ ใหม คับ เลือก นาน นิด เขา หา พูด ประมาณ ว่า ไม่ มีเงิน ผม คิด น่ะ ไม่ มีเงิน แล้ วจะ เข้าไป เพื่อ อะไร ฝาก น่ะ คับ สาขา แถว พารา ก้อน
# ...

# %%
import fasttext
model = fasttext.train_supervised(input="burger.train", epoch=40)

# %%
model.test("burger.test")
# Out:
# (12, 0.8333333333333334, 0.8333333333333334)

# %%
model.predict("ผม เคย เป็น แฟน เบอร์เกอร์ คิง แต่ ปัจจุบัน คุณภาพ ลดลง มหาศาล จึง ต้อง ขอ บอกลา ทั้ง ที่ มี โปรโมชั่น ออกมา อย่าง ต่อเนื่อง ปัจจุบัน เนื้อ คุณภาพ ปานกลาง แต่ มา เจอ การย่าง เนื้อ ระดับ แย่ ผล ก็ คือ ความ ไม่ อร่อย และ ราคา เดียวกัน นี้ หา เบอร์เกอร์ ที่อื่น ทาน ได้ อร่อย กว่า มาก ราคา อาหาร เกือบ เท่ากับ เบอร์เกอร์ คิง ต่างประเทศ แต่ ผม ไม่ เข้าใจ ว่า ทำไม คุณภาพ ได้ ต่างกัน ลิบลับ ขนาด นี้")
# Out:
# (('__label__neg',), array([0.54410189]))

# %%
model.predict("น่า ทาน อร่อย ดี ครับ")
# Out:
# (('__label__pos',), array([0.93361855]))
