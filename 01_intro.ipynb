# %% [markdown]
# # **หัวข้อ 1**

# %% [markdown]
# ## หัวข้อ 1.1

# %%
# !ls
# Out:
# 502378.png  sample_data  SKRU.png

# %%
# !wget https://www.skru.ac.th/th/assets/images/SKRU.png
# Out:
# --2023-07-12 03:04:37--  https://www.skru.ac.th/th/assets/images/SKRU.png
# Resolving www.skru.ac.th (www.skru.ac.th)... 202.29.16.40, 2001:3c8:900b:80::12
# Connecting to www.skru.ac.th (www.skru.ac.th)|202.29.16.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551035 (4.3M) [image/png]
# Saving to: ‘SKRU.png’
#
# SKRU.png            100%[===================>]   4.34M  1.08MB/s    in 4.8s
#
# 2023-07-12 03:04:43 (932 KB/s) - ‘SKRU.png’ saved [4551035/4551035]

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # **หัวข้อ 2**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
dataset_path="/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/"

# %%
import pandas as pd

# Create a simple dataframe
df = pd.DataFrame({
    'A': [6, 2, 0],
    'B': [4, 3, 0],
    'C': [4, 4, 2]
})


# Write it to a CSV file in your Google Drive
df.to_csv(dataset_path+'644234002.csv', index=False)

df
# Out:
#    A  B  C
# 0  6  4  4
# 1  2  3  4
# 2  0  0  2

# %%
print(df)
# Out:
#    A  B  C
# 0  6  4  4
# 1  2  3  4
# 2  0  0  2

# %%
df_002 = pd.read_csv(dataset_path+'644234002.csv')

# Print the dataframe
df_002
# Out:
#    A  B  C
# 0  6  4  4
# 1  2  3  4
# 2  0  0  2

# %%
sd = pd.read_csv(dataset_path+'student.csv')

# Print the dataframe
sd
# Out:
#    StudentID FirstName  LastName
# 0  644234002     ฟากิฮ     ราแดง
# 1  644234006  นิเฟาวัส  นิยมเดชา
# 2  644234042  เสฏฐวุฒิ   พรหมทอง
