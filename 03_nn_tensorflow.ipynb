# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**ION**

# %%
#การเรียกใช้ libary pandas
import pandas as pd

df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/ion.csv', index_col=0)
df
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 347   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 348   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 349   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 350   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 351   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
# ...

# %%
#แสดง good bad เป็นเลข 0,1
df['Class'] = df['Class'].map({'good': 0, 'bad': 1})
df
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 347   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 348   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 349   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 350   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 351   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
# ...

# %%
#แสดงส่วนหัว 5 แถว
df.head(5)
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 1  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 2 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 3  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 4  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 5 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 1 -0.54487  0.18641 -0.45300      0
# ...

# %%
#แสดงส่วนท้าย 3 แถว
df.tail(3)
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 349   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 350   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 351   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#          V10  ...      V26      V27      V28      V29      V30      V31  \
# 349  0.02446  ...  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459
# 350  0.00110  ... -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022
# 351 -0.09139  ... -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747
#
#          V32      V33      V34  Class
# 349  0.00442  0.92697 -0.00577      0
# 350 -0.03757  0.87403 -0.16243      0
# 351 -0.06678  0.85764 -0.06151      0
#
# [3 rows x 35 columns]

# %%
#จำนวนแถวและคอลลัมทั้งหมด
df.shape
# Out:
# (351, 35)

# %%
#sampling ของ df แต่ไปเก็บใน train ไม่มีอะไรเปลี่ยนแปลงกับ df
#แบ่ง 70% เป็น train อีก 30 เป็น valid
df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)
#df_train.index
df_valid
# Out:
#      V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 10    1   0 -0.01864 -0.08459  0.00000  0.00000  0.00000  0.00000  0.11470
# 24    0   0 -1.00000  1.00000  0.00000  0.00000  0.00000  0.00000 -1.00000
# 26    1   0  1.00000  0.57820  1.00000 -1.00000  1.00000 -1.00000  1.00000
# 29    1   0  1.00000  0.08380  1.00000  0.17387  1.00000 -0.13308  0.98172
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 337   1   0  0.88420  0.36724  0.67123  0.67382  0.39613  0.86399  0.02424
# 339   1   0  0.32789  0.11042  0.15970  0.29308  0.14020  0.74485 -0.25131
# 345   1   0  0.76046  0.01092  0.86335  0.00258  0.85821  0.00384  0.79988
# 347   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 350   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
#
# ...

# %%
import pandas as pd
from IPython.display import display

ion = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/ion.csv', index_col=0)
display(ion.head())

df = ion.copy()
df['Class'] = df['Class'].map({'good': 0, 'bad': 1})

df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)

df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)
df_train.dropna(axis=1, inplace=True) # drop the empty feature in column 2
df_valid.dropna(axis=1, inplace=True)

X_train = df_train.drop('Class', axis=1)
X_valid = df_valid.drop('Class', axis=1)

y_train = df_train['Class']
y_valid = df_valid['Class']
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 1   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 2   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 3   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 4   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 5   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 1  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 2 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 3  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 4  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 5 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 1 -0.54487  0.18641 -0.45300   good
# ...

# %%
X_train.shape
# Out:
# (246, 33)

# %%
y_train.shape
# Out:
# (246,)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[33]),
    layers.Dense(4, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=0, # hide the output because we have so many epochs
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(),
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.6532
# Best Validation Accuracy: 0.8476

# %% [markdown]
# #**Mobile Train**

# %%
mobile_train=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/mobile_train.csv')

# %%
import pandas as pd
from IPython.display import display
from tensorflow import keras
from tensorflow.keras import layers

# %%
mobile_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mobile_train.shape
# Out:
# (2000, 21)

# %%
mobile_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mobile_train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
mobile_train.price_range.unique()
# Out:
# array([1, 2, 3, 0])

# %%
mobile_train.loc[mobile_train.price_range==1 ,'price_range']=0

# %%
mobile_train.price_range.unique()
# Out:
# array([0, 2, 3])

# %%
mobile_train.loc[  (mobile_train.price_range==2) | (mobile_train.price_range==3)  ,'price_range']=1

# %%
mobile_train.price_range.unique()
# Out:
# array([0, 1])

# %%
df_train = mobile_train.sample(frac=0.7, random_state=0)
df_valid = mobile_train.drop(df_train.index)

y_train = df_train['price_range']
y_valid = df_valid['price_range']

# %%
X_train = df_train.drop('price_range', axis=1)
X_valid = df_valid.drop('price_range', axis=1)

# %%
X_train.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 405            1454     1          0.5         1   1       0          34
# 1190           1092     1          0.5         1  10       0          11
# 1132           1524     1          1.8         1   0       0          10
# 731            1807     1          2.1         0   2       0          49
# 1754           1086     1          1.7         1   0       1          43
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 405     0.7         83        4   3        250      1033  3419     7     5
# 1190    0.5        167        3  14        468       571   737    14     4
# 1132    0.6        174        4   1        154       550  2678    16     5
# 731     0.8        125        1  10        337      1384  1906    17    13
# 1754    0.2        111        6   1         56      1150  3285    11     5
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %%
import pandas as pd
from IPython.display import display

mobile_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2566_1_4613646_AI_and_DS/Datasets/mobile_train.csv')
display(mobile_train.head())

df = mobile_train.copy()
#df['price_range'] = df['price_range'].map({'good': 0, 'bad': 1})


df_train = df.sample(frac=0.7, random_state=0)
df_valid = df.drop(df_train.index)

max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)

df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)
df_train.dropna(axis=1, inplace=True) # drop the empty feature in column 2
df_valid.dropna(axis=1, inplace=True)

X_train = df_train.drop('price_range', axis=1)
X_valid = df_valid.drop('price_range', axis=1)

y_train = df_train['price_range']
y_valid = df_valid['price_range']
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
X_train.shape
# Out:
# (1400, 20)

# %%
y_train.shape
# Out:
# (1400,)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[20]),
    layers.Dense(4, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 4)                 84
#
#  dense_7 (Dense)             (None, 4)                 20
#
#  dense_8 (Dense)             (None, 1)                 5
#
# ...
# Total params: 109
# Trainable params: 109
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=0, # hide the output because we have so many epochs
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(),
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.3682
# Best Validation Accuracy: 0.4983
